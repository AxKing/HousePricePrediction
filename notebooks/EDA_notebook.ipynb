# %% [markdown]
# # California Housing Prices
# ### by Anthony Medina

# %% [markdown]
# # Exploratory Data Analysis (EDA) Notebook
#
# ## EDA Table of Contents
# 1. Introduction and Notebook Objectives
# 2. Imports and Load the data
# 3. Investigating Individual Distributions
# 4. Investigating Bivariate Relationships
#     * Visualizing relationships
#     * When relevant, calculating statistics
# 5. Conclusions and Next Steps

# %% [markdown]
# ### 1. Introduction and Notebook Objectives
# We'll be exploring a cleaned up version of the [(Kaggle-California Housing Prices)](https://www.kaggle.com/datasets/camnugent/california-housing-prices) data set.
#
# The objective is to explore the relationships of the data features and understand how the features compare to the response variable. In this case we'll be attempting to predict the median house price for a given area.

# %% [markdown]
# ### 2. Imports and load the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Import the data from the cleaned data folder
house_data = pd.read_csv('../cleaned_data/ready_for_EDA.csv', index_col = 0)

# %% [markdown]
# ### 3. Investigating Individual Distributions
# * Really get to know our target variable
#
# * Exploration of individual variables
# * 'longitude'
# * 'latitude'
# * 'housing_median_age'
# * 'total_rooms'
# * 'total_ bedrooms'
# * 'population'
# * 'households'
# * 'median_income'
# * 'ocean_proximity'

# %%
house_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0          880             129
# 1    -122.22     37.86                21.0         7099            1106
# 2    -122.24     37.85                52.0         1467             190
# 3    -122.25     37.85                52.0         1274             235
# 4    -122.25     37.85                52.0         1627             280
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126        83252.0            452600.0        NEAR BAY
# 1        2401        1138        83014.0            358500.0        NEAR BAY
# 2         496         177        72574.0            352100.0        NEAR BAY
# 3         558         219        56431.0            341300.0        NEAR BAY
# 4         565         259        38462.0            342200.0        NEAR BAY

# %%
house_data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms             int64
# total_bedrooms          int64
# population              int64
# households              int64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
house_data['median_house_value'].describe()
# Out:
# count     20433.000000
# mean     206864.413155
# std      115435.667099
# min       14999.000000
# 25%      119500.000000
# 50%      179700.000000
# 75%      264700.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
_ = plt.hist(house_data['median_house_value'], bins = 20)
_ = plt.xlabel('Middle House Value')
_ = plt.ylabel('Count')
plt.show()

# %%
exspensive = house_data[house_data['median_house_value'] >= 450000]['median_house_value']

# %%
_ = plt.hist(exspensive, bins = 10)
_ = plt.xlabel('Houses Over 450000')
_ = plt.ylabel('Count')
plt.show()

# %%
house_data['longitude'].describe()
# Out:
# count    20433.000000
# mean      -119.570689
# std          2.003578
# min       -124.350000
# 25%       -121.800000
# 50%       -118.490000
# 75%       -118.010000
# max       -114.310000
# Name: longitude, dtype: float64

# %%
house_data['longitude'].value_counts()
# Out:
# -118.31    159
# -118.30    157
# -118.29    146
# -118.27    141
# -118.32    141
#           ...
# -123.72      1
# -115.95      1
# -115.80      1
# -116.55      1
# -123.47      1
# Name: longitude, Length: 844, dtype: int64

# %%
_ = plt.hist(house_data['longitude'], bins = 10)
_ = plt.xlabel('Spread of Longitude')
_ = plt.ylabel('Count')
plt.show()

# %%
house_data['latitude'].describe()
# Out:
# count    20433.000000
# mean        35.633221
# std          2.136348
# min         32.540000
# 25%         33.930000
# 50%         34.260000
# 75%         37.720000
# max         41.950000
# Name: latitude, dtype: float64

# %%
house_data['latitude'].value_counts()
# Out:
# 34.06    241
# 34.08    232
# 34.05    229
# 34.07    227
# 34.04    215
#         ...
# 32.54      1
# 40.74      1
# 40.24      1
# 34.84      1
# 35.88      1
# Name: latitude, Length: 861, dtype: int64

# %%
_ = plt.hist(house_data['latitude'], bins = 10)
_ = plt.xlabel('Spread of Latitude')
_ = plt.ylabel('Count')
plt.show()

# %%
house_data['housing_median_age'].describe()
# Out:
# count    20433.000000
# mean        28.633094
# std         12.591805
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: housing_median_age, dtype: float64

# %%
house_data['housing_median_age'].value_counts()
# Out:
# 52.0    1265
# 36.0     856
# 35.0     818
# 16.0     762
# 17.0     694
# 34.0     682
# 26.0     611
# 33.0     609
# 25.0     562
# 32.0     560
# 18.0     560
# 37.0     528
# 15.0     507
# 19.0     499
# 27.0     482
# 24.0     473
# 30.0     470
# 28.0     468
# 20.0     462
# 29.0     453
# 31.0     449
# 23.0     445
# 21.0     444
# 14.0     410
# 22.0     395
# 38.0     385
# 39.0     366
# 42.0     363
# 44.0     353
# 43.0     351
# 40.0     301
# 13.0     298
# 41.0     293
# 45.0     286
# 10.0     263
# 11.0     252
# 46.0     245
# 5.0      242
# 12.0     236
# 9.0      204
# 8.0      203
# 47.0     195
# 4.0      190
# 48.0     174
# 7.0      173
# 6.0      157
# 50.0     135
# 49.0     133
# 3.0       62
# 2.0       58
# 51.0      47
# 1.0        4
# Name: housing_median_age, dtype: int64

# %%
_ = plt.hist(house_data['housing_median_age'], bins = 30)
_ = plt.xlabel('Spread of Median House Age')
_ = plt.ylabel('Count')
plt.show()

# %%
house_data['total_rooms'].describe()
# Out:
# count    20433.000000
# mean      2636.504233
# std       2185.269567
# min          2.000000
# 25%       1450.000000
# 50%       2127.000000
# 75%       3143.000000
# max      39320.000000
# Name: total_rooms, dtype: float64

# %%
house_data['total_rooms'].value_counts()
# Out:
# 1527     18
# 1582     17
# 1613     17
# 2127     16
# 1471     15
#          ..
# 539       1
# 6442      1
# 5367      1
# 5122      1
# 10035     1
# Name: total_rooms, Length: 5911, dtype: int64

# %%
_ = plt.hist(house_data['total_rooms'], bins = 100)
_ = plt.xlabel('Rooms Per Block')
_ = plt.ylabel('Count')
plt.show()

# %%
house_data['total_bedrooms'].describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
house_data['total_bedrooms'].value_counts()
# Out:
# 280     55
# 331     51
# 345     50
# 343     49
# 393     49
#         ..
# 2961     1
# 1915     1
# 1215     1
# 3298     1
# 1052     1
# Name: total_bedrooms, Length: 1923, dtype: int64

# %%
_ = plt.hist(house_data['total_bedrooms'], bins = 10)
_ = plt.xlabel('Spread of Total Bedrooms')
_ = plt.ylabel('Count')
plt.show()

# %%
house_data['population'].describe()
# Out:
# count    20433.000000
# mean      1424.946949
# std       1133.208490
# min          3.000000
# 25%        787.000000
# 50%       1166.000000
# 75%       1722.000000
# max      35682.000000
# Name: population, dtype: float64

# %%
house_data['population'].value_counts()
# Out:
# 891     25
# 1052    24
# 850     24
# 1227    24
# 761     24
#         ..
# 2913     1
# 2757     1
# 3392     1
# 6897     1
# 6912     1
# Name: population, Length: 3879, dtype: int64

# %%
_ = plt.hist(house_data['population'], bins = 10)
_ = plt.xlabel('Spread of Population')
_ = plt.ylabel('Count')
plt.show()

# %%
_ = sns.catplot(x= 'population', data = house_data, kind='box', sym='')
_ = plt.xlabel('Population Data without Outliers')

# %%
house_data['households'].describe()
# Out:
# count    20433.000000
# mean       499.433465
# std        382.299226
# min          1.000000
# 25%        280.000000
# 50%        409.000000
# 75%        604.000000
# max       6082.000000
# Name: households, dtype: float64

# %%
house_data['households'].value_counts()
# Out:
# 306     57
# 335     56
# 282     55
# 386     55
# 429     54
#         ..
# 996      1
# 1699     1
# 2528     1
# 1565     1
# 1818     1
# Name: households, Length: 1809, dtype: int64

# %%
house_data['households'].nunique()
# Out:
# 1809

# %%
_ = plt.hist(house_data['households'], bins = 10)
_ = plt.xlabel('Number of Households within a City Block')
_ = plt.ylabel('Count')
plt.show()

# %%
house_data['median_income'].describe()
# Out:
# count     20433.000000
# mean      38711.616013
# std       18992.912493
# min        4999.000000
# 25%       25637.000000
# 50%       35365.000000
# 75%       47440.000000
# max      150001.000000
# Name: median_income, dtype: float64

# %%
house_data['median_income'].value_counts()
# Out:
# 31250.0     49
# 150001.0    48
# 28750.0     46
# 41250.0     44
# 26250.0     44
#             ..
# 60723.0      1
# 46992.0      1
# 54042.0      1
# 67744.0      1
# 20943.0      1
# Name: median_income, Length: 12825, dtype: int64

# %%
_ = plt.hist(house_data['median_income'], bins = 10)
_ = plt.xlabel('Median Income Spread')
_ = plt.ylabel('Count')
plt.show()

# %%
house_data['ocean_proximity'].describe()
# Out:
# count         20433
# unique            5
# top       <1H OCEAN
# freq           9034
# Name: ocean_proximity, dtype: object

# %%
house_data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
sns.countplot(x=house_data['ocean_proximity'])
# Out:
# <AxesSubplot:xlabel='ocean_proximity', ylabel='count'>

# %% [markdown]
# ### 4. Investigating Bivariate Relationships
# * Visualizing relationships
# * When relevant, calculating statistics
#     * median_house_value vs longitude
#     * median_house_value vs latitude
#     * median_house_value vs housing_median_age
#     * median_house_value vs total_rooms
#     * median_house_value vs total_ bedrooms
#     * median_house_value vs population
#     * median_house_value vs households
#     * median_house_value vs median_income
#     * median_house_value vs ocean_proximity

# %%
house_data.corr(method='pearson')
# Out:
# /var/folders/b0/x4p60r3n3dz3lbgp1_bgg05h0000gn/T/ipykernel_41042/2935668342.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   house_data.corr(method='pearson')
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# ...

# %%
# It looks like median_income and median_house_value are the closest related.

# %%
sns.pairplot(house_data)

# %%
sns.heatmap(house_data.corr(), annot=True)
# Out:
# /var/folders/b0/x4p60r3n3dz3lbgp1_bgg05h0000gn/T/ipykernel_41042/1875011573.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(house_data.corr())
# <AxesSubplot:>

# %%
# Looks like I could further explore median house value vs median income and median house value vs households

# %%
# Median House Value and Median Income
_ = sns.scatterplot(x='median_house_value', y='median_income', data=house_data, color = 'blue')

# %%
# Best Linear Fit of median_house_value vs median_income
slope, intercept = np.polyfit(house_data['median_house_value'], house_data['median_income'], 1)
x_values = np.array([0, 500000])
y_values = slope * x_values + intercept

# %%
_ = sns.scatterplot(x='median_house_value', y='median_income', data=house_data, color = 'blue')
_ = plt.plot(x_values, y_values, color = 'red')
plt.show()

# %%
# Median House Value and Households

# %%
_ = sns.scatterplot(x='median_house_value', y='households', data=house_data, color = 'blue')

# %%
slope, intercept = np.polyfit(house_data['median_house_value'], house_data['households'], 1)
x_values = np.array([0, 500000])
y_values = slope * x_values + intercept

# %%
_ = sns.scatterplot(x='median_house_value', y='households', data=house_data, color = 'blue')
_ = plt.plot(x_values, y_values, color = 'red')
plt.show()

# %% [markdown]
# ### 5. Conclusions and Next Steps
#
# #### Conclusions
# The lack of Island data points might be an issue.
#
# #### Next Steps
# Now that the data has been explored, it's time to pre-process and model it.
